# %% [markdown]
# # Importing Requirements

# %%
from main import Simulation
import numpy as np

# %% [markdown]
# # Setting Simulation Hyper parameters

# %%
# a test setting
hparams = {
    'rooms': [
        np.array([12, 10], np.double),
        np.array([8, 13, 6], np.double),
    ],
    'max_patient_wait' : np.array([30], dtype=np.double),
    'arrival_rate' : np.array([5], dtype=np.double),
    'reception_mu' : np.array([8], dtype=np.double) 
}

# %% [markdown]
# # Simulating & Result 5

# %% [markdown]
# For 1,000,000 patients:

# %%
sim = Simulation(10**6, hparams)

# %%
sim.simulate()
# Out:
#   0%|          | 1417/1000000 [00:00<06:03, 2748.64it/s]
# Needed Number of simulations for 95% accuracy is: 788
# 100%|██████████| 1000000/1000000 [03:52<00:00, 4299.34it/s]

# %% [markdown]
# For 10,000,000 patients:

# %%
sim = Simulation(10**7, hparams)

# %%
sim.simulate()
# Out:
#   0%|          | 1859/10000000 [00:00<1:00:05, 2773.30it/s]
# Needed Number of simulations for 95% accuracy is: 884
# 100%|██████████| 10000000/10000000 [41:41<00:00, 3996.92it/s]

# %% [markdown]
# # Results
# ## 1 - 4

# %% [markdown]
# For 1,000,000 patients:

# %%
print(sim)
sim.print_sub_results()
# Out:
# Simulation:
# 	* mean time spent: 0.4389023 (0.4525357, 0.3151458)
# 	* mean waiting time: 0.2075 (0.2212, 0.08357)
# 	* patients 1000000 (900769, 99231) - bored 0 (0, 0)
# Reception:
# Que #0 - time:[200018.310284]
# 	* len: 0 - (0, 0)
# 	* mean-len 1.891:(1.765, 0.1259)
# 	* mean-wait 0.207:(0.2206, 0.08332)
# 	* patients 1000000 (900769, 99231) - bored 0 (0, 0)
#
# Rooms:
# Que #1 - time:[200017.91088756]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.00206:(0.001948, 0.0001127)
# 	* mean-wait 0.0009307:(0.0009831, 0.0004527)
# 	* patients 497749 (448581, 49168) - bored 0 (0, 0)
#
# Que #2 - time:[200018.310284]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.000272:(0.0002564, 1.561e-05)
# 	* mean-wait 0.0001147:(0.000121, 5.761e-05)
# 	* patients 502251 (452188, 50063) - bored 0 (0, 0)

# %% [markdown]
# For 10,000,000 patients:

# %%
print(sim)
sim.print_sub_results()
# Out:
# Simulation:
# 	* mean time spent: 0.4394562 (0.4532774, 0.315125)
# 	* mean waiting time: 0.2081 (0.222, 0.08353)
# 	* patients 10000000 (8999574, 1000426) - bored 0 (0, 0)
# Reception:
# Que #0 - time:[2000202.50815855]
# 	* len: 0 - (0, 0)
# 	* mean-len 1.894:(1.766, 0.1273)
# 	* mean-wait 0.2076:(0.2214, 0.08324)
# 	* patients 10000000 (8999574, 1000426) - bored 0 (0, 0)
#
# Rooms:
# Que #1 - time:[2000202.2828486]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.002109:(0.001983, 0.000126)
# 	* mean-wait 0.0009437:(0.0009914, 0.0005153)
# 	* patients 4990141 (4490719, 499422) - bored 0 (0, 0)
#
# Que #2 - time:[2000202.50815855]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.0002628:(0.0002503, 1.248e-05)
# 	* mean-wait 0.000114:(0.0001211, 5.013e-05)
# 	* patients 5009859 (4508855, 501004) - bored 0 (0, 0)

# %% [markdown]
# ## 6

# %%
sim.find_optimum_service_rate()
# Out:
# Answer: 113.90625

# %% [markdown]
# # Bonus

# %% [markdown]
# ## 1. Response Time Frequency

# %% [markdown]
# For 1,000,000 patients:

# %%
sim.plot_response_time_frequency()

# %% [markdown]
# For 10,000,000 patients:

# %%
sim.plot_response_time_frequency()

# %% [markdown]
# ## 2. Wait Time Frequency

# %% [markdown]
# For 1,000,000 patients:

# %%
sim.plot_wait_frequency()

# %% [markdown]
# For 10,000,000 patients:

# %%
sim.plot_wait_frequency()

# %% [markdown]
# ## 3. Attendance Frequency

# %% [markdown]
# For 1,000,000 patients:

# %%
sim.plot_attendance_frequency()

# %% [markdown]
# For 10,000,000 patients:

# %%
sim.plot_attendance_frequency()

# %% [markdown]
# ## 4. Attendance

# %% [markdown]
# For 1,000,000 patients:

# %%
sim.plot_attendance_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# For 10,000,000 patients:

# %%
sim.plot_attendance_history()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 5. Queue Lengths

# %% [markdown]
# ### Reception

# %% [markdown]
# For 1,000,000 patients:

# %%
sim.reception.plot_len_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# For 10,000,000 patients:

# %%
sim.reception.plot_len_history()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Rooms

# %% [markdown]
# For 1,000,000 patients:

# %%
for room in sim.reception.rooms:
    room.plot_len_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# For 10,000,000 patients:

# %%
for room in sim.reception.rooms:
    room.plot_len_history()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
