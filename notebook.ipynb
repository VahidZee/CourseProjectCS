# %% [markdown]
# # Importing Requirements

# %%
from main import Simulation
import numpy as np

# %% [markdown]
# # Setting Simulation Hyper parameters

# %%
# a test setting
hparams = {
    'rooms': [
        np.array([12, 10], np.double),
        np.array([8, 13, 6], np.double),
    ],
    'max_patient_wait' : np.array([30], dtype=np.double),
    'arrival_rate' : np.array([5], dtype=np.double),
    'reception_mu' : np.array([8], dtype=np.double) 
}

# %% [markdown]
# # Simulating & Result 5

# %%
sim = Simulation(10**6, hparams)

# %%
sim.simulate()
# Out:
#   0%|          | 1417/1000000 [00:00<06:03, 2748.64it/s]
# Needed Number of simulations for 95% accuracy is: 788
# 100%|██████████| 1000000/1000000 [03:52<00:00, 4299.34it/s]

# %% [markdown]
# # Results
# ## 1 - 4

# %%
print(sim)
sim.print_sub_results()
# Out:
# Simulation:
# 	* mean time spent: 0.4389023 (0.4525357, 0.3151458)
# 	* mean waiting time: 0.2075 (0.2212, 0.08357)
# 	* patients 1000000 (900769, 99231) - bored 0 (0, 0)
# Reception:
# Que #0 - time:[200018.310284]
# 	* len: 0 - (0, 0)
# 	* mean-len 1.891:(1.765, 0.1259)
# 	* mean-wait 0.207:(0.2206, 0.08332)
# 	* patients 1000000 (900769, 99231) - bored 0 (0, 0)
#
# Rooms:
# Que #1 - time:[200017.91088756]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.00206:(0.001948, 0.0001127)
# 	* mean-wait 0.0009307:(0.0009831, 0.0004527)
# 	* patients 497749 (448581, 49168) - bored 0 (0, 0)
#
# Que #2 - time:[200018.310284]
# 	* len: 0 - (0, 0)
# 	* mean-len 0.000272:(0.0002564, 1.561e-05)
# 	* mean-wait 0.0001147:(0.000121, 5.761e-05)
# 	* patients 502251 (452188, 50063) - bored 0 (0, 0)

# %% [markdown]
# ## 6

# %%
sim.find_optimum_service_rate()

# %% [markdown]
# # Bonus

# %% [markdown]
# ## 1. Response Time Frequency

# %%
sim.plot_response_time_frequency()

# %% [markdown]
# ## 2. Wait Time Frequency

# %%
sim.plot_wait_frequency()

# %% [markdown]
# ## 3. Attendance Frequency

# %%
sim.plot_attendance_frequency()

# %% [markdown]
# ## 4. Attendance

# %%
sim.plot_attendance_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 5. Queue Lengths

# %% [markdown]
# ### Reception

# %%
sim.reception.plot_len_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### Rooms

# %%
for room in sim.reception.rooms:
    room.plot_len_history()
# Out:
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/vahidzee/opt/miniconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
